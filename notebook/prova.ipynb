# %%
import sys
import os
import logging
import pandas as pd
import numpy as np
from pathlib import Path

# Get the Project Root Directory
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

from src.core.loader import load_data, error_handling , check_time_gaps
from src.core.engine import run
from src.strategy.strategy import Strategy

# Configure Logging to display in Notebook
logging.basicConfig(
    stream=sys.stdout, 
    level=logging.INFO, 
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    force=True
)

logger = logging.getLogger("Notebook_Test")
logger.info("Logging configured. Ready for testing.")
# Out:
# 2025-12-04 22:26:59,872 - Notebook_Test - INFO - Logging configured. Ready for testing.

# %%
file_path = os.path.join(project_root, 'data', 'raw', 'NQ.csv')

# %%
df = load_data(file_path)
# Out:
# 2025-12-04 22:26:59,923 - loader - INFO - Successfully loaded 6315 rows
# 2025-12-04 22:26:59,927 - loader - WARNING - Intervals > 1 day between adjacent records were found
# /Users/baudotedua/Dropbox/Mac/Desktop/hurst_pullback/hurst-pullback/src/core/loader.py:112: UserWarning: Intervals > 1 day between adjacent records were found
#   warnings.warn(

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
